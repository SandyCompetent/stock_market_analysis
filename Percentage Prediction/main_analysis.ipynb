# %% [markdown]
# ## Stock Price Prediction with Sentiment Analysis

# %%
# !pip install charset-normalizer
# !pip install pandas_ta
# !pip install --upgrade pandas_ta

# %%
# To reload the imported modules automatically
# %load_ext autoreload
# %autoreload 2

# %%
# Import necessary libraries and modules
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import ReduceLROnPlateau
import warnings
import os

# Import modules
import config as cfg
import data_processing as dp
import sentiment_analysis as sa
import model as mdl
import utils as ut
# Out:
# /opt/anaconda3/envs/tf_metal/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
warnings.filterwarnings('ignore')
np.random.seed(42)
tf.random.set_seed(42)

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
os.makedirs(cfg.DATASET_DIR, exist_ok=True)

# %% [markdown]
# ### Load and Analyze News Data

# %%
sentiment_csv_path = f"{cfg.DATASET_DIR}/{cfg.STOCK_SYMBOL}_daily_sentiment.csv"

if cfg.UPDATE_SENTIMENT_CSV or not os.path.exists(sentiment_csv_path):
    print("Generating new sentiment data and saving to CSV...")
    news_df = dp.load_and_analyze_news_data(cfg.NEWS_DATA_FILE, cfg.STOCK_SYMBOL)
    company_sentiment_df = sa.process_news_sentiment(news_df, cfg.STOCK_SYMBOL)
    daily_sentiment_df = sa.aggregate_daily_sentiment(company_sentiment_df)
    ut.save_dataframe(daily_sentiment_df, sentiment_csv_path)
else:
    print(f"Loading existing sentiment data from {sentiment_csv_path}...")
    daily_sentiment_df = pd.read_csv(sentiment_csv_path, index_col='Date', parse_dates=True)

print("Sentiment data ready.")
# Out:
# Generating new sentiment data and saving to CSV...
# Loading and selecting news data...
# 🎯 Selected target stock: NVDA (3133 articles)
# \n📰 Processing news sentiment for NVDA...
# Initializing sentiment analyzer with model: ProsusAI/finbert
# Using device: cpu
# Analyzer initialized successfully.
# Analyzing 3133 headlines in batches of 32...
#   0%|          | 0/98 [00:00<?, ?it/s]
# \nSentiment distribution:\n Sentiment
# neutral     1573
# positive     887
# negative     673
# Name: count, dtype: int64
# \n📊 Aggregating daily sentiment scores...
# DataFrame saved to Dataset/NVDA_daily_sentiment.csv
# Sentiment data ready.

# %% [markdown]
# ### Fetch Stock Data and Calculate Technical Indicators

# %%
START_DATE, END_DATE = ut.calculate_dynamic_date_range(daily_sentiment_df)

stock_filename = f"{cfg.STOCK_SYMBOL}_stock_data_{START_DATE}_to_{END_DATE}.csv"
stock_csv_path = os.path.join(cfg.DATASET_DIR, stock_filename)

if cfg.UPDATE_STOCK_CSV or not os.path.exists(stock_csv_path):
    print(f"Fetching new stock data from yfinance ({START_DATE} to {END_DATE})...")
    stock_data = dp.fetch_stock_data(cfg.STOCK_SYMBOL, START_DATE, END_DATE)
    if stock_data is not None:
        stock_data.to_csv(stock_csv_path)
        print(f"Stock data saved to {stock_csv_path}")
else:
    print(f"Loading existing stock data from {stock_csv_path}...")
    stock_data = pd.read_csv(stock_csv_path, index_col='Date', parse_dates=True)

# Calculate technical indicators from the loaded/fetched data
tech_data = dp.calculate_technical_indicators(stock_data)
print("Technical indicators calculated.")
# Out:
# Fetching new stock data from yfinance (2010-03-03 to 2020-06-10)...
# \n📈 Fetching stock data for NVDA...
# Successfully fetched 2586 days of data.
# Stock data saved to Dataset/NVDA_stock_data_2010-03-03_to_2020-06-10.csv
# Technical indicators calculated.

# %% [markdown]
# ### Prepare data for technical models

# %%
X_train_tech, X_test_tech, y_train_tech, y_test_tech, scaler_tech = mdl.prepare_data_for_lstm(
    tech_data, cfg.BASELINE_FEATURES, cfg.BASELINE_TARGET, cfg.SEQUENCE_LENGTH, cfg.TEST_SIZE
)

# %% [markdown]
# ### Prepare Data for Single Layer LSTM Model

# %%
print("\n--- Running LSTM Model (Single-Layer) ---")
baseline_model = mdl.build_single_layer_lstm((X_train_tech.shape[1], X_train_tech.shape[2]))
baseline_model.summary()
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.0001, verbose=1)
baseline_history = baseline_model.fit(
    X_train_tech, y_train_tech, epochs=cfg.EPOCHS, batch_size=cfg.BATCH_SIZE,
    validation_split=0.2, callbacks=[reduce_lr], verbose=1
)
# Out:
# --- Running LSTM Model (Single-Layer) ---
# 2025-07-28 22:10:12.270443: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2025-07-28 22:10:12.270510: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-07-28 22:10:12.270521: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753737012.270532  188462 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1753737012.270550  188462 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128)            │        70,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 70,273 (274.50 KB)
#  Trainable params: 70,273 (274.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 2025-07-28 22:10:12.664468: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0156 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0058 - val_loss: 0.0088 - learning_rate: 0.0010
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0047 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0043 - val_loss: 0.0068 - learning_rate: 0.0010
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0043 - val_loss: 0.0063 - learning_rate: 0.0010
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0043 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0041 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - val_loss: 0.0068 - learning_rate: 0.0010
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0041 - val_loss: 0.0066 - learning_rate: 0.0010
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - val_loss: 0.0055 - learning_rate: 0.0010
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - val_loss: 0.0069 - learning_rate: 0.0010
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0056 - learning_rate: 0.0010
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0059 - learning_rate: 0.0010
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 27/100
# 13/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0038
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0050 - learning_rate: 5.0000e-04
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 5.0000e-04
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 32/100
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0036
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0049 - learning_rate: 5.0000e-04
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 2.5000e-04
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 2.5000e-04
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 2.5000e-04
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 2.5000e-04
# Epoch 37/100
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0047 - learning_rate: 2.5000e-04
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.2500e-04
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.2500e-04
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.2500e-04
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.2500e-04
# Epoch 42/100
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.2500e-04
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0036 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0036 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0036 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0037 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0048 - learning_rate: 1.0000e-04
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0036 - val_loss: 0.0047 - learning_rate: 1.0000e-04

# %% [markdown]
# #### Evaluate Baseline Model

# %%
# Create a scaler specifically for the 'Pct_Change' target column
pct_change_scaler = MinMaxScaler().fit(tech_data[['Pct_Change']])

# Predict and inverse transform
base_preds = baseline_model.predict(X_test_tech)
y_test_tech_scaled = pct_change_scaler.inverse_transform(y_test_tech.reshape(-1, 1))
base_preds_scaled = pct_change_scaler.inverse_transform(base_preds)

# Calculate metrics and plot
baseline_metrics = ut.calculate_metrics(y_test_tech_scaled, base_preds_scaled, 'Single-Layer LSTM')
test_dates_tech = tech_data.index[-len(y_test_tech_scaled):]
ut.plot_model_results(baseline_history, y_test_tech_scaled, base_preds_scaled, test_dates_tech, cfg.STOCK_SYMBOL,
                      'Single-Layer LSTM')
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Plot saved to Output/NVDA_Single-Layer_LSTM_analysis.png

# %% [markdown]
# ### Multi-Layer LSTM Model

# %%
print("\\n--- Running Multi-Layer Model ---")
multi_layer_model = mdl.build_multi_layer_lstm((X_train_tech.shape[1], X_train_tech.shape[2]))
multi_layer_model.summary()
multi_layer_history = multi_layer_model.fit(
    X_train_tech, y_train_tech, epochs=cfg.EPOCHS, batch_size=cfg.BATCH_SIZE,
    validation_split=0.2, callbacks=[reduce_lr], verbose=1
)
# Out:
# \n--- Running Multi-Layer Model ---
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 30, 128)        │        70,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         1,625 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 121,203 (473.45 KB)
#  Trainable params: 121,203 (473.45 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0205 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0047 - val_loss: 0.0117 - learning_rate: 0.0010
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0046 - val_loss: 0.0069 - learning_rate: 0.0010
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0043 - val_loss: 0.0064 - learning_rate: 0.0010
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0040 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0041 - val_loss: 0.0059 - learning_rate: 0.0010
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0041 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - val_loss: 0.0055 - learning_rate: 0.0010
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0042 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0038 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0040 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - val_loss: 0.0060 - learning_rate: 0.0010
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 17/100
# 14/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0038
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 5.0000e-04
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0045 - learning_rate: 5.0000e-04
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0045 - learning_rate: 5.0000e-04
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 5.0000e-04
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0045 - learning_rate: 5.0000e-04
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0045 - learning_rate: 5.0000e-04
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 5.0000e-04
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 5.0000e-04
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 5.0000e-04
# Epoch 29/100
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0038
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0037 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0038 - val_loss: 0.0052 - learning_rate: 2.5000e-04
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0037 - val_loss: 0.0057 - learning_rate: 2.5000e-04
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0056 - learning_rate: 2.5000e-04
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0037 - val_loss: 0.0053 - learning_rate: 2.5000e-04
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0037
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0037 - val_loss: 0.0056 - learning_rate: 2.5000e-04
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0058 - learning_rate: 1.2500e-04
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0059 - learning_rate: 1.2500e-04
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0037 - val_loss: 0.0059 - learning_rate: 1.2500e-04
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0057 - learning_rate: 1.2500e-04
# Epoch 39/100
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0037
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0037 - val_loss: 0.0059 - learning_rate: 1.2500e-04
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0057 - learning_rate: 1.0000e-04
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0060 - learning_rate: 1.0000e-04
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0060 - learning_rate: 1.0000e-04
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0035 - val_loss: 0.0058 - learning_rate: 1.0000e-04
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0036 - val_loss: 0.0060 - learning_rate: 1.0000e-04
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0061 - learning_rate: 1.0000e-04
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0035 - val_loss: 0.0063 - learning_rate: 1.0000e-04
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0062 - learning_rate: 1.0000e-04
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0064 - learning_rate: 1.0000e-04
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0063 - learning_rate: 1.0000e-04
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0064 - learning_rate: 1.0000e-04
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0064 - learning_rate: 1.0000e-04
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0063 - learning_rate: 1.0000e-04
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0062 - learning_rate: 1.0000e-04
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0063 - learning_rate: 1.0000e-04
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0036 - val_loss: 0.0064 - learning_rate: 1.0000e-04
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0067 - learning_rate: 1.0000e-04
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0068 - learning_rate: 1.0000e-04
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0037 - val_loss: 0.0065 - learning_rate: 1.0000e-04
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0035 - val_loss: 0.0065 - learning_rate: 1.0000e-04
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0036 - val_loss: 0.0067 - learning_rate: 1.0000e-04
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0067 - learning_rate: 1.0000e-04
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0065 - learning_rate: 1.0000e-04
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0064 - learning_rate: 1.0000e-04
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0066 - learning_rate: 1.0000e-04
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0037 - val_loss: 0.0069 - learning_rate: 1.0000e-04
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0068 - learning_rate: 1.0000e-04
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0068 - learning_rate: 1.0000e-04
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0036 - val_loss: 0.0065 - learning_rate: 1.0000e-04
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0065 - learning_rate: 1.0000e-04
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0067 - learning_rate: 1.0000e-04
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0067 - learning_rate: 1.0000e-04
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0066 - learning_rate: 1.0000e-04
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0068 - learning_rate: 1.0000e-04
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0069 - learning_rate: 1.0000e-04
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0070 - learning_rate: 1.0000e-04
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0069 - learning_rate: 1.0000e-04
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0071 - learning_rate: 1.0000e-04
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0069 - learning_rate: 1.0000e-04
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0035 - val_loss: 0.0069 - learning_rate: 1.0000e-04
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0035 - val_loss: 0.0071 - learning_rate: 1.0000e-04
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0035 - val_loss: 0.0077 - learning_rate: 1.0000e-04
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0036 - val_loss: 0.0078 - learning_rate: 1.0000e-04
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0078 - learning_rate: 1.0000e-04
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0036 - val_loss: 0.0074 - learning_rate: 1.0000e-04
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0076 - learning_rate: 1.0000e-04
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0077 - learning_rate: 1.0000e-04
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0076 - learning_rate: 1.0000e-04
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0075 - learning_rate: 1.0000e-04
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0035 - val_loss: 0.0074 - learning_rate: 1.0000e-04
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0035 - val_loss: 0.0074 - learning_rate: 1.0000e-04
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0035 - val_loss: 0.0078 - learning_rate: 1.0000e-04
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0080 - learning_rate: 1.0000e-04
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0077 - learning_rate: 1.0000e-04
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0078 - learning_rate: 1.0000e-04
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0035 - val_loss: 0.0082 - learning_rate: 1.0000e-04
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0036 - val_loss: 0.0083 - learning_rate: 1.0000e-04
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036 - val_loss: 0.0081 - learning_rate: 1.0000e-04
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0035 - val_loss: 0.0084 - learning_rate: 1.0000e-04
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0081 - learning_rate: 1.0000e-04
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0036 - val_loss: 0.0084 - learning_rate: 1.0000e-04

# %%
# Predict using the trained multi-layer model
multi_preds = multi_layer_model.predict(X_test_tech)

# Inverse transform predictions and actual values using the Pct_Change scaler
multi_preds_scaled = pct_change_scaler.inverse_transform(multi_preds)
# Note: y_test_tech_scaled is already calculated in the baseline evaluation cell

# Calculate metrics and plot results
multi_layer_metrics = ut.calculate_metrics(y_test_tech_scaled, multi_preds_scaled, 'Multi-Layer LSTM')
ut.plot_model_results(multi_layer_history, y_test_tech_scaled, multi_preds_scaled, test_dates_tech, cfg.STOCK_SYMBOL,
                      'Multi-Layer LSTM')
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Plot saved to Output/NVDA_Multi-Layer_LSTM_analysis.png

# %% [markdown]
# ### Sentiment-Enhanced LSTM Model (Single-Layer)

# %%
print("\\n--- Running Sentiment-Enhanced Model ---")
enhanced_full_data = dp.create_enhanced_dataset(tech_data, daily_sentiment_df)
X_train_enh, X_test_enh, y_train_enh, y_test_enh, scaler_enh = mdl.prepare_data_for_lstm(
    enhanced_full_data, cfg.ENHANCED_FEATURES, cfg.ENHANCED_TARGET, cfg.SEQUENCE_LENGTH, cfg.TEST_SIZE
)

enhanced_model = mdl.build_single_layer_lstm((X_train_enh.shape[1], X_train_enh.shape[2]))
enhanced_model.summary()

enhanced_history = enhanced_model.fit(
    X_train_enh, y_train_enh, epochs=cfg.EPOCHS, batch_size=cfg.BATCH_SIZE,
    validation_split=0.2, callbacks=[reduce_lr], verbose=1
)
# Out:
# \n--- Running Sentiment-Enhanced Model ---
#
# 🔗 Merging sentiment and technical data...
# Enhanced dataset shape: (2387, 30)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 128)            │        71,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 71,809 (280.50 KB)
#  Trainable params: 71,809 (280.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0576 - val_loss: 0.0317 - learning_rate: 0.0010
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0081 - val_loss: 0.0088 - learning_rate: 0.0010
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0050 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0048 - val_loss: 0.0061 - learning_rate: 0.0010
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0045 - val_loss: 0.0067 - learning_rate: 0.0010
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0047 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0043 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0043 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0043 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0043 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 11/100
# 14/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0043
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0043 - val_loss: 0.0059 - learning_rate: 0.0010
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0042 - val_loss: 0.0047 - learning_rate: 5.0000e-04
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - val_loss: 0.0047 - learning_rate: 5.0000e-04
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0042 - val_loss: 0.0049 - learning_rate: 5.0000e-04
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0042 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 16/100
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0040
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0041 - val_loss: 0.0046 - learning_rate: 2.5000e-04
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0041 - val_loss: 0.0047 - learning_rate: 2.5000e-04
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - val_loss: 0.0047 - learning_rate: 2.5000e-04
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0040 - val_loss: 0.0046 - learning_rate: 2.5000e-04
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - val_loss: 0.0046 - learning_rate: 2.5000e-04
# Epoch 22/100
# 14/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0043
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0042 - val_loss: 0.0046 - learning_rate: 2.5000e-04
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0041 - val_loss: 0.0046 - learning_rate: 1.2500e-04
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - val_loss: 0.0046 - learning_rate: 1.2500e-04
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - val_loss: 0.0046 - learning_rate: 1.2500e-04
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0041 - val_loss: 0.0046 - learning_rate: 1.2500e-04
# Epoch 27/100
# 14/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0041
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0041 - val_loss: 0.0046 - learning_rate: 1.2500e-04
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0041 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0040 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0040 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0040 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0040 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0036 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04

# %% [markdown]
# #### Evaluate Sentiment-Enhanced Model

# %%
# Create a new scaler specifically for the enhanced dataset's 'Pct_Change' column
pct_change_scaler_enh = MinMaxScaler().fit(enhanced_full_data[['Pct_Change']])

# Predict and inverse transform
enh_preds = enhanced_model.predict(X_test_enh)
y_test_enh_scaled = pct_change_scaler_enh.inverse_transform(y_test_enh.reshape(-1, 1))
enh_preds_scaled = pct_change_scaler_enh.inverse_transform(enh_preds)

# Calculate metrics and plot
enhanced_metrics = ut.calculate_metrics(y_test_enh_scaled, enh_preds_scaled, 'Enhanced LSTM')
test_dates_enh = enhanced_full_data.index[-len(y_test_enh_scaled):]
ut.plot_model_results(enhanced_history, y_test_enh_scaled, enh_preds_scaled, test_dates_enh, cfg.STOCK_SYMBOL,
                      'Enhanced LSTM')
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Plot saved to Output/NVDA_Enhanced_LSTM_analysis.png

# %% [markdown]
# ### Sentiment-Enhanced LSTM Model (Multi-Layer)

# %%
print("\\n--- Running Multi-Layer Enhanced Model ---")
multi_enhanced_model = mdl.build_multi_layer_lstm((X_train_enh.shape[1], X_train_enh.shape[2]))
multi_enhanced_history = multi_enhanced_model.fit(
    X_train_enh, y_train_enh, epochs=cfg.EPOCHS, batch_size=cfg.BATCH_SIZE,
    validation_split=0.2, callbacks=[reduce_lr], verbose=1
)
# Out:
# \n--- Running Multi-Layer Enhanced Model ---
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0293 - val_loss: 0.0059 - learning_rate: 0.0010
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0055 - val_loss: 0.0043 - learning_rate: 0.0010
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0048 - val_loss: 0.0042 - learning_rate: 0.0010
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0044 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0045 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0042 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0041
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0041 - val_loss: 0.0064 - learning_rate: 0.0010
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0041 - val_loss: 0.0047 - learning_rate: 5.0000e-04
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0041 - val_loss: 0.0043 - learning_rate: 5.0000e-04
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0040 - val_loss: 0.0042 - learning_rate: 5.0000e-04
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0043 - val_loss: 0.0042 - learning_rate: 5.0000e-04
# Epoch 12/100
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0041
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0040 - val_loss: 0.0042 - learning_rate: 5.0000e-04
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0041 - val_loss: 0.0045 - learning_rate: 2.5000e-04
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - val_loss: 0.0045 - learning_rate: 2.5000e-04
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0039 - val_loss: 0.0044 - learning_rate: 2.5000e-04
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0039 - val_loss: 0.0044 - learning_rate: 2.5000e-04
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0040 - val_loss: 0.0045 - learning_rate: 2.5000e-04
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.2500e-04
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.2500e-04
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0040 - val_loss: 0.0045 - learning_rate: 1.2500e-04
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0039 - val_loss: 0.0045 - learning_rate: 1.2500e-04
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0044 - learning_rate: 1.2500e-04
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0039 - val_loss: 0.0044 - learning_rate: 1.0000e-04
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0039 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0044 - learning_rate: 1.0000e-04
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0039 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0048 - learning_rate: 1.0000e-04
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0044 - learning_rate: 1.0000e-04
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0039 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0037 - val_loss: 0.0049 - learning_rate: 1.0000e-04
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0049 - learning_rate: 1.0000e-04
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0037 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0050 - learning_rate: 1.0000e-04
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0049 - learning_rate: 1.0000e-04
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0050 - learning_rate: 1.0000e-04
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - val_loss: 0.0049 - learning_rate: 1.0000e-04
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0048 - learning_rate: 1.0000e-04
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0047 - learning_rate: 1.0000e-04
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0036 - val_loss: 0.0048 - learning_rate: 1.0000e-04
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0050 - learning_rate: 1.0000e-04
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0049 - learning_rate: 1.0000e-04
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0052 - learning_rate: 1.0000e-04
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0049 - learning_rate: 1.0000e-04
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0052 - learning_rate: 1.0000e-04
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0051 - learning_rate: 1.0000e-04
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0051 - learning_rate: 1.0000e-04
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0049 - learning_rate: 1.0000e-04
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0050 - learning_rate: 1.0000e-04
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0049 - learning_rate: 1.0000e-04
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0052 - learning_rate: 1.0000e-04
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0051 - learning_rate: 1.0000e-04
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0049 - learning_rate: 1.0000e-04
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0049 - learning_rate: 1.0000e-04
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0050 - learning_rate: 1.0000e-04
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0036 - val_loss: 0.0050 - learning_rate: 1.0000e-04
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0053 - learning_rate: 1.0000e-04
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0037 - val_loss: 0.0052 - learning_rate: 1.0000e-04
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0052 - learning_rate: 1.0000e-04
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0036 - val_loss: 0.0053 - learning_rate: 1.0000e-04
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - val_loss: 0.0049 - learning_rate: 1.0000e-04
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0052 - learning_rate: 1.0000e-04
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - val_loss: 0.0051 - learning_rate: 1.0000e-04
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0036 - val_loss: 0.0051 - learning_rate: 1.0000e-04
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0052 - learning_rate: 1.0000e-04
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0052 - learning_rate: 1.0000e-04
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0054 - learning_rate: 1.0000e-04
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0057 - learning_rate: 1.0000e-04
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0037 - val_loss: 0.0055 - learning_rate: 1.0000e-04
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0036 - val_loss: 0.0052 - learning_rate: 1.0000e-04
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0055 - learning_rate: 1.0000e-04
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0052 - learning_rate: 1.0000e-04

# %%
# Predict using the trained multi-layer enhanced model
multi_enh_preds = multi_enhanced_model.predict(X_test_enh)

# Inverse transform predictions and actual values
multi_enh_preds_scaled = pct_change_scaler_enh.inverse_transform(multi_enh_preds)
# Note: y_test_enh_scaled is already calculated in the single-layer enhanced evaluation cell

# Calculate metrics and plot
multi_enhanced_metrics = ut.calculate_metrics(y_test_enh_scaled, multi_enh_preds_scaled, 'Multi-Layer Enhanced LSTM')
ut.plot_model_results(multi_enhanced_history, y_test_enh_scaled, multi_enh_preds_scaled, test_dates_enh,
                      cfg.STOCK_SYMBOL, 'Multi-Layer Enhanced LSTM')
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Plot saved to Output/NVDA_Multi-Layer_Enhanced_LSTM_analysis.png

# %% [markdown]
# ### Final Performance Comparison

# %%
naive_preds = np.roll(y_test_tech_scaled, 1)
naive_preds[0] = y_test_tech_scaled[0]
naive_metrics = ut.calculate_metrics(y_test_tech_scaled, naive_preds, 'Naive Baseline')

# Performance DataFrame
all_metrics_df = pd.DataFrame([
    naive_metrics,
    baseline_metrics,
    enhanced_metrics,
    multi_layer_metrics,
    multi_enhanced_metrics,
]).round(4)

print("\n📊 COMPREHENSIVE PERFORMANCE COMPARISON")
print("-" * 60)
print(all_metrics_df.to_string(index=False))

# Define which metrics are 'lower is better' vs 'higher is better'
metrics_to_evaluate = {
    'RMSE': 'min',
    'MAE': 'min',
    'Directional_Accuracy': 'max'
}

print("-" * 30)
print("Best Model for Each Metric")
print("-" * 30)

for metric, method in metrics_to_evaluate.items():
    if method == 'min':
        # For RMSE and MAE, the lowest score is the best
        winner_idx = all_metrics_df[metric].idxmin()
    else: # method == 'max'
        # For Directional Accuracy, the highest score is the best
        winner_idx = all_metrics_df[metric].idxmax()

    # Get the row of the winning model
    winner_row = all_metrics_df.loc[winner_idx]

    model_name = winner_row['Model']
    score = winner_row[metric]

    print(f"{metric} : {model_name} (Score: {score:.4f})")
# Out:
# 📊 COMPREHENSIVE PERFORMANCE COMPARISON
# ------------------------------------------------------------
#                     Model   RMSE    MAE  Directional_Accuracy
#            Naive Baseline 6.1740 4.2357               86.6109
#         Single-Layer LSTM 6.2307 4.0971               92.8870
#             Enhanced LSTM 4.9960 3.4903               92.8870
#          Multi-Layer LSTM 5.2850 4.0612               84.1004
# Multi-Layer Enhanced LSTM 4.5227 3.3106               92.8870
# ------------------------------
# Best Model for Each Metric
# ------------------------------
# RMSE : Multi-Layer Enhanced LSTM (Score: 4.5227)
# MAE : Multi-Layer Enhanced LSTM (Score: 3.3106)
# Directional_Accuracy : Single-Layer LSTM (Score: 92.8870)

# %%
ranking_df = all_metrics_df.copy()

ranking_df['RMSE_Rank'] = ranking_df['RMSE'].rank(method='min', ascending=True)
ranking_df['MAE_Rank'] = ranking_df['MAE'].rank(method='min', ascending=True)


ranking_df['DA_Rank'] = ranking_df['Directional_Accuracy'].rank(method='min', ascending=False)

ranking_df['Total_Rank'] = ranking_df['RMSE_Rank'] + ranking_df['MAE_Rank'] + ranking_df['DA_Rank']

final_ranking = ranking_df.sort_values(by='Total_Rank', ascending=True)

print("-" * 40)
print("\\n🏆 Overall Model Ranking (Best to Worst)")
print("-" * 40)
print(final_ranking[['Model', 'Total_Rank', 'RMSE', 'Directional_Accuracy']].reset_index(drop=True).to_string())
# Out:
# ----------------------------------------
# \n🏆 Overall Model Ranking (Best to Worst)
# ----------------------------------------
#                        Model  Total_Rank    RMSE  Directional_Accuracy
# 0  Multi-Layer Enhanced LSTM         3.0  4.5227               92.8870
# 1              Enhanced LSTM         5.0  4.9960               92.8870
# 2          Single-Layer LSTM        10.0  6.2307               92.8870
# 3           Multi-Layer LSTM        11.0  5.2850               84.1004
# 4             Naive Baseline        13.0  6.1740               86.6109

# %% [markdown]
# ### Plot Results

# %%
plot_data = {
    'Actual': {'dates': test_dates_enh, 'values': y_test_enh_scaled},  # Use enhanced dates/values for consistency
    'Baseline LSTM': {'dates': test_dates_tech, 'values': base_preds_scaled},
    'Multi-Layer LSTM': {'dates': test_dates_tech, 'values': multi_preds_scaled},
    'Enhanced LSTM': {'dates': test_dates_enh, 'values': enh_preds_scaled},
    'Multi-Layer Enhanced LSTM': {'dates': test_dates_enh, 'values': multi_enh_preds_scaled}
}
ut.plot_final_comparison(plot_data, cfg.STOCK_SYMBOL)
# Out:
# Plot saved to Output/NVDA_all_models_comparison.png
